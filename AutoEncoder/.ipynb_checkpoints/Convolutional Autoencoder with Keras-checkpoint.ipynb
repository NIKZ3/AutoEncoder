# %%
import os
import glob

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2

from keras.preprocessing import image
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D
from keras.layers import MaxPooling2D, Dropout, UpSampling2D
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,8))
img = cv2.imread('./input/train/101.png', 0)
plt.imshow(img, cmap='gray')
print(img.shape)
# Out:
# (420, 540)

# %%
TRAIN_IMAGES = glob.glob('./input/train/*.png')
CLEAN_IMAGES = glob.glob('./input/train_cleaned/*.png')
TEST_IMAGES = glob.glob('./input/test/*.png')

# %%
def load_image(path):
    image_list = np.zeros((len(path), 420, 540, 1))
    for i, fig in enumerate(path):
        img = image.load_img(fig, color_mode='grayscale', target_size=(420, 540))
        x = image.img_to_array(img).astype('float32')
        x = x / 255.0
        image_list[i] = x
    
    return image_list

# %%
x_train = load_image(TRAIN_IMAGES)
y_train = load_image(CLEAN_IMAGES)
x_test = load_image(TEST_IMAGES)

print(x_train.shape, x_test.shape)
# Out:
# (144, 420, 540, 1) (72, 420, 540, 1)

# %%
def train_val_split(x_train, y_train):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(x_train))
    train_idx = perm[:int(0.8 * len(x_train))]
    val_idx = perm[int(0.8 * len(x_train)):]
    return x_train[train_idx], y_train[train_idx], x_train[val_idx], y_train[val_idx]

x_train, y_train, x_val, y_val = train_val_split(x_train, y_train)
print(x_train.shape, x_val.shape)
# Out:
# (115, 420, 540, 1) (29, 420, 540, 1)

# %%
class Autoencoder():
    def __init__(self):
        self.img_rows = 420
        self.img_cols = 540
        self.channels = 1
        self.img_shape = (self.img_rows, self.img_cols, self.channels)
        
        optimizer = Adam(lr=0.001)
        
        self.autoencoder_model = self.build_model()
        self.autoencoder_model.compile(loss='mse', optimizer=optimizer)
        self.autoencoder_model.summary()
    
    def build_model(self):
        input_layer = Input(shape=self.img_shape)
        
        h = Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
        h = MaxPooling2D((2, 2), padding='same')(h)
        
        h = Conv2D(64, (3, 3), activation='relu', padding='same')(h)
        h = UpSampling2D((2, 2))(h)
        output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(h)
        
        return Model(input_layer, output_layer)
    
    def train_model(self, x_train, y_train, x_val, y_val, epochs, batch_size=20):
        early_stopping = EarlyStopping(monitor='val_loss',
                                       min_delta=0,
                                       patience=5,
                                       verbose=1, 
                                       mode='auto')
        history = self.autoencoder_model.fit(x_train, y_train,
                                             batch_size=batch_size,
                                             epochs=epochs,
                                             validation_data=(x_val, y_val),
                                             callbacks=[early_stopping])
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')
        plt.show()
    
    def eval_model(self, x_test):
        preds = self.autoencoder_model.predict(x_test)
        return preds

# %%
ae = Autoencoder()
ae.train_model(x_train, y_train, x_val, y_val, epochs=200, batch_size=20)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 420, 540, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 420, 540, 64)      640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 210, 270, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 210, 270, 64)      36928
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 420, 540, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 420, 540, 1)       577
# =================================================================
# Total params: 38,145
# Trainable params: 38,145
# Non-trainable params: 0
# _________________________________________________________________
# Train on 115 samples, validate on 29 samples
# Epoch 1/200
# 115/115 [==============================] - 9s 74ms/step - loss: 0.1685 - val_loss: 0.0913
# Epoch 2/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0747 - val_loss: 0.0701
# Epoch 3/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0722 - val_loss: 0.0731
# Epoch 4/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0708 - val_loss: 0.0642
# Epoch 5/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0610 - val_loss: 0.0585
# Epoch 6/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0546 - val_loss: 0.0509
# Epoch 7/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0471 - val_loss: 0.0423
# Epoch 8/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0385 - val_loss: 0.0336
# Epoch 9/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0304 - val_loss: 0.0272
# Epoch 10/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0251 - val_loss: 0.0235
# Epoch 11/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0216 - val_loss: 0.0206
# Epoch 12/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0190 - val_loss: 0.0185
# Epoch 13/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0172 - val_loss: 0.0169
# Epoch 14/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0157 - val_loss: 0.0154
# Epoch 15/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0144 - val_loss: 0.0141
# Epoch 16/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0132 - val_loss: 0.0131
# Epoch 17/200
# 115/115 [==============================] - 3s 28ms/step - loss: 0.0123 - val_loss: 0.0122
# Epoch 18/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 19/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 20/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0103 - val_loss: 0.0105
# Epoch 21/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0099 - val_loss: 0.0102
# Epoch 22/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 23/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0092 - val_loss: 0.0094
# Epoch 24/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0088 - val_loss: 0.0092
# Epoch 25/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 26/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 27/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 28/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0078 - val_loss: 0.0080
# Epoch 29/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0076 - val_loss: 0.0078
# Epoch 30/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 31/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 32/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 33/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 34/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 35/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0067 - val_loss: 0.0068
# Epoch 36/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 37/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 38/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 39/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 40/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 41/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 42/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0059 - val_loss: 0.0061
# Epoch 43/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 44/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0058 - val_loss: 0.0058
# Epoch 45/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 46/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 47/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 48/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 49/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 50/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 51/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 52/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 53/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 54/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 55/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 56/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0049 - val_loss: 0.0051
# Epoch 57/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 58/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0049 - val_loss: 0.0050
# Epoch 59/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 60/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 61/200
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 62/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 63/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 64/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 65/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 66/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 67/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 68/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 69/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 70/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 71/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 72/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 73/200
# 115/115 [==============================] - 4s 30ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 74/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 75/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 76/200
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 77/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 78/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0041 - val_loss: 0.0042
# Epoch 79/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 80/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 81/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 82/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 83/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 84/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 85/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 86/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 87/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 88/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 89/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 90/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 91/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 92/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 93/200
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 94/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0037 - val_loss: 0.0038
# Epoch 95/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 96/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 97/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 98/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 99/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 100/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 101/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 102/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 103/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 104/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 105/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 106/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 107/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 108/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035 - val_loss: 0.0036
# Epoch 109/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 110/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0034 - val_loss: 0.0035
# Epoch 111/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 112/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 113/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 114/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 115/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 116/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 117/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 118/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 119/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 120/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 121/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 122/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 123/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 124/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 125/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 126/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 127/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 128/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 129/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 130/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 131/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 132/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 133/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 134/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 135/200
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 136/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 137/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 138/200
# 115/115 [==============================] - 4s 30ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 139/200
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 140/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 141/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 142/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 143/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 144/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 145/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 146/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 147/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 148/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 149/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 150/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 151/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 152/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 153/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 154/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 155/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 156/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 157/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 158/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 159/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 160/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 161/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 162/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 163/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 164/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 165/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 166/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 167/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 168/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 169/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 170/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 171/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 172/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 173/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 174/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 175/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 176/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 177/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 178/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 179/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 180/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 181/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 182/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 183/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 184/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0028
# Epoch 185/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 186/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 187/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 188/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 189/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 190/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 191/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 192/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 193/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 194/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 195/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 196/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 197/200
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 198/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 199/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 200/200
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0024 - val_loss: 0.0025

# %%
preds = ae.eval_model(x_test)

# %%
preds_0 = preds[11] 
preds_0 = preds_0.reshape(420, 540)
x_test_0 = x_test[11] 
x_test_0 = x_test_0.reshape(420, 540)
plt.imshow(x_test_0, cmap='gray')

# %%
plt.imshow(preds_0, cmap='gray')

# %%
ae.autoencoder_model.save('autoencoder2.h5')

# %%
from keras.models import load_model
ae1 = Autoencoder()
ae1.autoencoder_model=load_model('autoencoder2.h5')
preds1 = ae1.eval_model(x_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 420, 540, 1)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 420, 540, 64)      640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 210, 270, 64)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 210, 270, 64)      36928
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 420, 540, 64)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 420, 540, 1)       577
# =================================================================
# Total params: 38,145
# Trainable params: 38,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds_1=preds1[10]
preds_1=preds_1.reshape(420, 540)
x_test_1=x_test[10]
x_test_1=x_test_1.reshape(420, 540)

# %%
plt.imshow(preds_1,cmap='gray')

# %%
plt.imshow(x_test_1,cmap='gray')
